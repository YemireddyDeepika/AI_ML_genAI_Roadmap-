# %% [markdown]
# **Backprop**

# %%
#Libraries
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt

# %%
#XOR dataset
x = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,1,1,0])

# %%
#Model
model = MLPClassifier(hidden_layer_sizes=(4,),
                      max_iter=2000,
                      learning_rate_init=0.1)
model.fit(x,y)
# Out:
# MLPClassifier(hidden_layer_sizes=(4,), learning_rate_init=0.1, max_iter=2000)

# %%
#Prediction
pred = model.predict(x)
acc = accuracy_score(y,pred)
print("Accuracy:",acc)
# Out:
# Accuracy: 1.0

# %%
##Visualization

#Create mesh grid
x_min, x_max = -0.5,1.5
y_min, y_max = -0.5, 1.5
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200),
                     np.linspace(y_min, y_max, 200))

#Predict for every point in grid
z = model.predict(np.c_[xx.ravel(), yy.ravel()])
z = z.reshape(xx.shape)

#Plot decision boundary
plt.contourf(xx, yy, z, alpha=0.3)

#Plot original XOR points
plt.scatter(x[:,0], x[:,1], c=y, s=100)

plt.title("MLP Decision Boundary for XOR")
plt.xlabel("Input 1")
plt.ylabel("Input 2")
plt.show()
