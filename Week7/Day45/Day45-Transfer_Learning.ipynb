# %% [raw]
# 1️. What is Transfer Learning?
#
# Transfer Learning = Using knowledge from an already trained model.
#
#
# Example:
#
# A CNN trained on millions of images (ImageNet)
#
# It already learned:
#
# edges
#
# colors
#
# shapes
#
# textures
#
# So we reuse this knowledge for your own dataset (animals, faces, etc.).

# %% [raw]
# 2. Why Transfer Learning is Important?
#
# Without transfer learning:
#
# Need huge dataset
#
# Training takes hours or days
#
# Accuracy may be low
#
# With transfer learning:
#
# ✅ Works with small dataset
# ✅ Training is very fast
# ✅ Accuracy is much higher
# ✅ Used in real industry projects

# %% [raw]
# 3.Real-Life Analogy
#
# Think like this:
#
# A doctor who already studied general medicine
#
# Learning a new disease is easier
# because basics are already known.
#
# Same in AI:
#
# Pretrained CNN = experienced doctor
# Your dataset = new disease to learn

# %% [raw]
# 4. Two Main Types of Transfer Learning
# 🔹 1. Feature Extraction (Most common for beginners)
#
# Use pretrained CNN
#
# Freeze all base layers
#
# Train only final classification layer
#
# 👉 Fast training + good accuracy
#
# 🔹 2. Fine-Tuning (Advanced step)
#
# Unfreeze top few layers
#
# Train with very small learning rate
#
# 👉 Gives higher accuracy
# 👉 Used in real production systems
#
# 5️⃣ Popular Pretrained Models (Very Important for Interviews)
#
# You must remember these names:
#
# VGG16 / VGG19
#
# ResNet50
#
# MobileNet
#
# EfficientNet
#
# 👉 Interview question:
# “Why MobileNet is used in mobile apps?”
# Because it is lightweight and fast.
#
# 6️⃣ Where Transfer Learning is Used in Real World
#
# Face recognition
#
# Medical image diagnosis
#
# Self-driving cars
#
# Security cameras
#
# Google Photos / Instagram filters
