# %% [raw]
# Running on mobile phone
#
# Real-time camera detection
# → Use MobileNet

# %% [raw]
# High accuracy medical imaging
#
# Powerful GPU available
# → Use ResNet

# %% [raw]
# High accuracy medical imaging
#
# Powerful GPU available
# → Use ResNet

# %% [markdown]
# **How to Load Othere model**

# %% [markdown]
# Load RestNet

# %% [raw]
# from tensorflow.keras.applications import RestNet50
#
# base_model = RestNet50(
#     weights = "imagenet",
#     include_top = False,
#     input_shape = (128,128,3)
# )

# %% [markdown]
# Load VGG

# %% [raw]
# from tensorflow.keras.applications import VGG16
#
# base_model = VGG16(
#     weights = "imagenet",
#     include_top = False,
#     input_shape = (128,128,3)
# )
