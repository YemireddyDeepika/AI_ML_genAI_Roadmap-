# %% [markdown]
# 1.Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.linear_model import LogisticRegression
from matplotlib.colors import ListedColormap

# %% [markdown]
# 2.Dataset

# %%
df = pd.read_csv('Wine.csv')

# %%
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# 1   3.40     1050                 1
# 2   3.17     1185                 1
# 3   3.45     1480                 1
# 4   2.93      735                 1

# %%
 df.isna().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# Customer_Segment        0
# dtype: int64

# %% [markdown]
# 3.Train Test Split

# %%
x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# 4.Feature Scaling

# %%
scaler = StandardScaler()
x_train_scaler = scaler.fit_transform(x_train)
x_test_scaler = scaler.transform(x_test)

# %% [markdown]
# 4.PCA Model

# %%
pca = PCA(n_components=2)
x_train_pca = pca.fit_transform(x_train_scaler)
x_test_pca = pca.transform(x_test_scaler)

# %%
variance =  pca.explained_variance_ratio_

# %%
variance
# Out:
# array([0.35900066, 0.18691934])

# %% [markdown]
# 5.Logistic Model

# %%
le = LogisticRegression()
le.fit(x_train_pca,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# 6.Prediction

# %%
y_pred = le.predict(x_test_pca)

# %% [markdown]
# 7.Evaluation

# %%
print("Accuracy Score:",accuracy_score(y_test,y_pred))
cm = confusion_matrix(y_test,y_pred)
print("Confusion Matrix:\n",cm)
# Out:
# Accuracy Score: 1.0
# Confusion Matrix:
#  [[14  0  0]
#  [ 0 14  0]
#  [ 0  0  8]]

# %%
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
x_set,y_set = x_train_pca,y_train
x1,x2= np.meshgrid(np.arange(start=x_set[:,0].min()-1,stop=x_set[:,0].max()+1,step=0.01),
                   np.arange(start=x_set[:,1].min()-1,stop=x_set[:,1].max()+1,step=0.01))
plt.contourf(
    x1, x2,
    le.predict(np.c_[x1.ravel(), x2.ravel()]).reshape(x1.shape),
    alpha=0.75,
    cmap=ListedColormap(('red', 'green', 'blue'))
)
plt.xlim(x1.min(),x1.max())
plt.ylim(x2.min(),x2.max())
#Plot Traing Points
for i,j in enumerate(np.unique(y_set)):
    plt.scatter(
        x_set[y_set == j,0],
        x_set[y_set == j,1],
        cmap = ListedColormap(('red','green','blue'))(i),
        label=j
    )
plt.title("Classifier Decision Boundary(Training Set)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
# Out:
# C:\Users\Deepika\AppData\Local\Temp\ipykernel_13592\375353261.py:14: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(
